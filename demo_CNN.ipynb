# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
path = "/content/gdrive/MyDrive/Colab Notebooks/EEG"
os.chdir(path)
os.listdir(path)
# Out:
# ['data', 'demo2.ipynb', 'demo3.ipynb', 'demo1.ipynb']

# %%
#导入数据
import numpy as np
import cv2
from cv2 import resize
from keras.utils import np_utils
img_size = 200

X_data = []
Y_data = []
index = 0
g = os.listdir("data/")
for filename in g:
  index=index+1
  data = np.load("data/"+filename)
  x = data['x']
  y = data['y']
  if index == 1:
    X_data = x
    Y_data = y
  else:
    X_data = np.concatenate((X_data,x),axis=0)
    Y_data = np.concatenate((Y_data,y),axis=0)
print(X_data.shape)
print(Y_data.shape)

# 打乱数据
xdata = X_data
ydata = Y_data
num = len(ydata)
index = np.arange(num)
np.random.shuffle(index)
xdata = xdata[index,:]
ydata = ydata[index]

# one-hot编码
ydata = np_utils.to_categorical(ydata)
in_shp = list(xdata.shape[1:])
length = in_shp[1]
chanal = in_shp[0]
print(xdata.shape)
print(ydata.shape)
# Out:
# (42308, 3000, 1)
# (42308,)
# (42308, 3000, 1)
# (42308, 5)

# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D, Conv1D
from keras.layers.convolutional import MaxPooling2D, MaxPooling1D
from tensorflow.keras.optimizers import SGD, RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam
from keras.constraints import maxnorm
from keras.utils import np_utils
from keras import backend as K
from keras import backend

# 参数设置
kerner_num = 8
epochs = 200
num_classes = ydata.shape[1]

# 构建训练集与测试集
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(xdata,ydata,test_size=0.25,random_state=654)

# CNN模型
def create_model(epochs=25):
    model = Sequential()
    model.add(Conv1D(16, kerner_num, input_shape=(x_train.shape[1],1), padding='same',strides = 2, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Conv1D(32, kerner_num, activation='relu', padding='same',strides = 2))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Conv1D(64, kerner_num, activation='relu', padding='same',strides = 2))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Conv1D(128, kerner_num, activation='relu', padding='same',strides = 2))
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model
model = create_model(epochs)
model.summary()
history = model.fit(x=x_train, y=y_train, epochs=epochs, batch_size=500, verbose=2,validation_data=(x_test, y_test))

DRSN_train_score = model.evaluate(x_train, y_train, batch_size=500, verbose=0)
print('Train loss:', DRSN_train_score[0])
print('Train accuracy:', DRSN_train_score[1])
DRSN_test_score = model.evaluate(x_test, y_test, batch_size=500, verbose=0)
print('Test loss:', DRSN_test_score[0])
print('Test accuracy:', DRSN_test_score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1500, 16)          144
#
#  dropout (Dropout)           (None, 1500, 16)          0
#
#  batch_normalization (BatchN  (None, 1500, 16)         64
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 750, 32)           4128
#
#  dropout_1 (Dropout)         (None, 750, 32)           0
#
#  batch_normalization_1 (Batc  (None, 750, 32)          128
#  hNormalization)
#
#  conv1d_2 (Conv1D)           (None, 375, 64)           16448
#
#  dropout_2 (Dropout)         (None, 375, 64)           0
#
#  batch_normalization_2 (Batc  (None, 375, 64)          256
#  hNormalization)
#
#  conv1d_3 (Conv1D)           (None, 188, 128)          65664
#
#  flatten (Flatten)           (None, 24064)             0
#
#  dense (Dense)               (None, 256)               6160640
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 6,248,757
# Trainable params: 6,248,533
# Non-trainable params: 224
# _________________________________________________________________
# Epoch 1/200
# 64/64 - 19s - loss: 4.1086 - accuracy: 0.3825 - val_loss: 1.4423 - val_accuracy: 0.2766 - 19s/epoch - 300ms/step
# Epoch 2/200
# 64/64 - 12s - loss: 1.3274 - accuracy: 0.4296 - val_loss: 1.1411 - val_accuracy: 0.5511 - 12s/epoch - 182ms/step
# Epoch 3/200
# 64/64 - 12s - loss: 1.0816 - accuracy: 0.5785 - val_loss: 0.7793 - val_accuracy: 0.7419 - 12s/epoch - 183ms/step
# Epoch 4/200
# 64/64 - 12s - loss: 0.8806 - accuracy: 0.6642 - val_loss: 0.7443 - val_accuracy: 0.7593 - 12s/epoch - 184ms/step
# Epoch 5/200
# 64/64 - 12s - loss: 0.8026 - accuracy: 0.6968 - val_loss: 0.7414 - val_accuracy: 0.7543 - 12s/epoch - 186ms/step
# Epoch 6/200
# 64/64 - 12s - loss: 0.7456 - accuracy: 0.7293 - val_loss: 0.7163 - val_accuracy: 0.7551 - 12s/epoch - 183ms/step
# Epoch 7/200
# 64/64 - 12s - loss: 0.6945 - accuracy: 0.7438 - val_loss: 0.9013 - val_accuracy: 0.6782 - 12s/epoch - 186ms/step
# Epoch 8/200
# 64/64 - 12s - loss: 0.6671 - accuracy: 0.7565 - val_loss: 0.6062 - val_accuracy: 0.7934 - 12s/epoch - 183ms/step
# Epoch 9/200
# 64/64 - 12s - loss: 0.6390 - accuracy: 0.7634 - val_loss: 0.6243 - val_accuracy: 0.7842 - 12s/epoch - 183ms/step
# Epoch 10/200
# 64/64 - 12s - loss: 0.6036 - accuracy: 0.7790 - val_loss: 0.5630 - val_accuracy: 0.7804 - 12s/epoch - 183ms/step
# Epoch 11/200
# 64/64 - 12s - loss: 0.5854 - accuracy: 0.7828 - val_loss: 0.6438 - val_accuracy: 0.7602 - 12s/epoch - 183ms/step
# Epoch 12/200
# 64/64 - 12s - loss: 0.5641 - accuracy: 0.7920 - val_loss: 0.5008 - val_accuracy: 0.8088 - 12s/epoch - 183ms/step
# Epoch 13/200
# 64/64 - 12s - loss: 0.5537 - accuracy: 0.7962 - val_loss: 0.7213 - val_accuracy: 0.7252 - 12s/epoch - 185ms/step
# Epoch 14/200
# 64/64 - 12s - loss: 0.5327 - accuracy: 0.8013 - val_loss: 0.5393 - val_accuracy: 0.7901 - 12s/epoch - 186ms/step
# Epoch 15/200
# 64/64 - 12s - loss: 0.5268 - accuracy: 0.8065 - val_loss: 0.6642 - val_accuracy: 0.7585 - 12s/epoch - 183ms/step
# Epoch 16/200
# 64/64 - 12s - loss: 0.5179 - accuracy: 0.8092 - val_loss: 0.6090 - val_accuracy: 0.7762 - 12s/epoch - 187ms/step
# Epoch 17/200
# 64/64 - 12s - loss: 0.5047 - accuracy: 0.8138 - val_loss: 0.5150 - val_accuracy: 0.8141 - 12s/epoch - 184ms/step
# Epoch 18/200
# 64/64 - 12s - loss: 0.5042 - accuracy: 0.8138 - val_loss: 0.4752 - val_accuracy: 0.8214 - 12s/epoch - 187ms/step
# Epoch 19/200
# 64/64 - 12s - loss: 0.4926 - accuracy: 0.8163 - val_loss: 0.6101 - val_accuracy: 0.7753 - 12s/epoch - 184ms/step
# Epoch 20/200
# 64/64 - 12s - loss: 0.4869 - accuracy: 0.8207 - val_loss: 0.6695 - val_accuracy: 0.7542 - 12s/epoch - 184ms/step
# Epoch 21/200
# 64/64 - 12s - loss: 0.4759 - accuracy: 0.8237 - val_loss: 0.5424 - val_accuracy: 0.8048 - 12s/epoch - 186ms/step
# Epoch 22/200
# 64/64 - 12s - loss: 0.4708 - accuracy: 0.8263 - val_loss: 0.4949 - val_accuracy: 0.8156 - 12s/epoch - 185ms/step
# Epoch 23/200
# 64/64 - 12s - loss: 0.4608 - accuracy: 0.8268 - val_loss: 0.4654 - val_accuracy: 0.8380 - 12s/epoch - 184ms/step
# Epoch 24/200
# 64/64 - 12s - loss: 0.4560 - accuracy: 0.8301 - val_loss: 0.4380 - val_accuracy: 0.8403 - 12s/epoch - 183ms/step
# Epoch 25/200
# 64/64 - 12s - loss: 0.4539 - accuracy: 0.8300 - val_loss: 0.5575 - val_accuracy: 0.7961 - 12s/epoch - 184ms/step
# Epoch 26/200
# 64/64 - 12s - loss: 0.4456 - accuracy: 0.8331 - val_loss: 0.5697 - val_accuracy: 0.8053 - 12s/epoch - 183ms/step
# Epoch 27/200
# 64/64 - 12s - loss: 0.4387 - accuracy: 0.8365 - val_loss: 0.4550 - val_accuracy: 0.8349 - 12s/epoch - 183ms/step
# Epoch 28/200
# 64/64 - 12s - loss: 0.4265 - accuracy: 0.8397 - val_loss: 0.5649 - val_accuracy: 0.8066 - 12s/epoch - 183ms/step
# Epoch 29/200
# 64/64 - 12s - loss: 0.4271 - accuracy: 0.8404 - val_loss: 0.4734 - val_accuracy: 0.8266 - 12s/epoch - 183ms/step
# Epoch 30/200
# 64/64 - 12s - loss: 0.4255 - accuracy: 0.8418 - val_loss: 0.5934 - val_accuracy: 0.7962 - 12s/epoch - 183ms/step
# Epoch 31/200
# 64/64 - 12s - loss: 0.4198 - accuracy: 0.8450 - val_loss: 0.5144 - val_accuracy: 0.8120 - 12s/epoch - 183ms/step
# Epoch 32/200
# 64/64 - 12s - loss: 0.4168 - accuracy: 0.8464 - val_loss: 0.4398 - val_accuracy: 0.8401 - 12s/epoch - 183ms/step
# Epoch 33/200
# 64/64 - 12s - loss: 0.4042 - accuracy: 0.8488 - val_loss: 0.4763 - val_accuracy: 0.8283 - 12s/epoch - 183ms/step
# Epoch 34/200
# 64/64 - 12s - loss: 0.4022 - accuracy: 0.8493 - val_loss: 0.5010 - val_accuracy: 0.8271 - 12s/epoch - 183ms/step
# Epoch 35/200
# 64/64 - 12s - loss: 0.3994 - accuracy: 0.8496 - val_loss: 0.6082 - val_accuracy: 0.7673 - 12s/epoch - 183ms/step
# Epoch 36/200
# 64/64 - 12s - loss: 0.3932 - accuracy: 0.8535 - val_loss: 0.4753 - val_accuracy: 0.8289 - 12s/epoch - 183ms/step
# Epoch 37/200
# 64/64 - 12s - loss: 0.3909 - accuracy: 0.8524 - val_loss: 0.7446 - val_accuracy: 0.7590 - 12s/epoch - 186ms/step
# Epoch 38/200
# 64/64 - 12s - loss: 0.3855 - accuracy: 0.8537 - val_loss: 0.5789 - val_accuracy: 0.7864 - 12s/epoch - 183ms/step
# Epoch 39/200
# 64/64 - 12s - loss: 0.3887 - accuracy: 0.8566 - val_loss: 0.4363 - val_accuracy: 0.8399 - 12s/epoch - 183ms/step
# Epoch 40/200
# 64/64 - 12s - loss: 0.3783 - accuracy: 0.8567 - val_loss: 0.4993 - val_accuracy: 0.8199 - 12s/epoch - 183ms/step
# Epoch 41/200
# 64/64 - 12s - loss: 0.3789 - accuracy: 0.8579 - val_loss: 0.5474 - val_accuracy: 0.7992 - 12s/epoch - 183ms/step
# Epoch 42/200
# 64/64 - 12s - loss: 0.3757 - accuracy: 0.8565 - val_loss: 0.5244 - val_accuracy: 0.8128 - 12s/epoch - 183ms/step
# Epoch 43/200
# 64/64 - 12s - loss: 0.3687 - accuracy: 0.8626 - val_loss: 0.5576 - val_accuracy: 0.7971 - 12s/epoch - 183ms/step
# Epoch 44/200
# 64/64 - 12s - loss: 0.3699 - accuracy: 0.8613 - val_loss: 0.4425 - val_accuracy: 0.8452 - 12s/epoch - 184ms/step
# Epoch 45/200
# 64/64 - 12s - loss: 0.3651 - accuracy: 0.8607 - val_loss: 0.4803 - val_accuracy: 0.8322 - 12s/epoch - 183ms/step
# Epoch 46/200
# 64/64 - 12s - loss: 0.3597 - accuracy: 0.8653 - val_loss: 0.5094 - val_accuracy: 0.8187 - 12s/epoch - 183ms/step
# Epoch 47/200
# 64/64 - 12s - loss: 0.3567 - accuracy: 0.8647 - val_loss: 0.5599 - val_accuracy: 0.8212 - 12s/epoch - 183ms/step
# Epoch 48/200
# 64/64 - 12s - loss: 0.3493 - accuracy: 0.8669 - val_loss: 0.4988 - val_accuracy: 0.8375 - 12s/epoch - 183ms/step
# Epoch 49/200
# 64/64 - 12s - loss: 0.3508 - accuracy: 0.8663 - val_loss: 0.4519 - val_accuracy: 0.8446 - 12s/epoch - 183ms/step
# Epoch 50/200
# 64/64 - 12s - loss: 0.3435 - accuracy: 0.8700 - val_loss: 0.5471 - val_accuracy: 0.8133 - 12s/epoch - 183ms/step
# Epoch 51/200
# 64/64 - 12s - loss: 0.3449 - accuracy: 0.8686 - val_loss: 0.4626 - val_accuracy: 0.8318 - 12s/epoch - 183ms/step
# Epoch 52/200
# 64/64 - 12s - loss: 0.3416 - accuracy: 0.8723 - val_loss: 0.4824 - val_accuracy: 0.8272 - 12s/epoch - 183ms/step
# Epoch 53/200
# 64/64 - 12s - loss: 0.3355 - accuracy: 0.8752 - val_loss: 0.5124 - val_accuracy: 0.8284 - 12s/epoch - 183ms/step
# Epoch 54/200
# 64/64 - 12s - loss: 0.3338 - accuracy: 0.8740 - val_loss: 0.5305 - val_accuracy: 0.8085 - 12s/epoch - 183ms/step
# Epoch 55/200
# 64/64 - 12s - loss: 0.3277 - accuracy: 0.8766 - val_loss: 0.5370 - val_accuracy: 0.8254 - 12s/epoch - 183ms/step
# Epoch 56/200
# 64/64 - 12s - loss: 0.3280 - accuracy: 0.8761 - val_loss: 0.5932 - val_accuracy: 0.8107 - 12s/epoch - 183ms/step
# Epoch 57/200
# 64/64 - 12s - loss: 0.3222 - accuracy: 0.8800 - val_loss: 0.4899 - val_accuracy: 0.8296 - 12s/epoch - 183ms/step
# Epoch 58/200
# 64/64 - 12s - loss: 0.3263 - accuracy: 0.8767 - val_loss: 0.5285 - val_accuracy: 0.8344 - 12s/epoch - 183ms/step
# Epoch 59/200
# 64/64 - 12s - loss: 0.3162 - accuracy: 0.8801 - val_loss: 0.7369 - val_accuracy: 0.8055 - 12s/epoch - 184ms/step
# Epoch 60/200
# 64/64 - 12s - loss: 0.3208 - accuracy: 0.8831 - val_loss: 0.5208 - val_accuracy: 0.8257 - 12s/epoch - 183ms/step
# Epoch 61/200
# 64/64 - 12s - loss: 0.3136 - accuracy: 0.8848 - val_loss: 0.5735 - val_accuracy: 0.8136 - 12s/epoch - 183ms/step
# Epoch 62/200
# 64/64 - 12s - loss: 0.3142 - accuracy: 0.8840 - val_loss: 0.5351 - val_accuracy: 0.8282 - 12s/epoch - 183ms/step
# Epoch 63/200
# 64/64 - 12s - loss: 0.3107 - accuracy: 0.8845 - val_loss: 0.5607 - val_accuracy: 0.8186 - 12s/epoch - 183ms/step
# Epoch 64/200
# 64/64 - 12s - loss: 0.2977 - accuracy: 0.8867 - val_loss: 0.5298 - val_accuracy: 0.8268 - 12s/epoch - 183ms/step
# Epoch 65/200
# 64/64 - 12s - loss: 0.3026 - accuracy: 0.8859 - val_loss: 0.5168 - val_accuracy: 0.8395 - 12s/epoch - 183ms/step
# Epoch 66/200
# 64/64 - 12s - loss: 0.3099 - accuracy: 0.8833 - val_loss: 0.5782 - val_accuracy: 0.8225 - 12s/epoch - 186ms/step
# Epoch 67/200
# 64/64 - 12s - loss: 0.2991 - accuracy: 0.8865 - val_loss: 0.5747 - val_accuracy: 0.8216 - 12s/epoch - 183ms/step
# Epoch 68/200
# 64/64 - 12s - loss: 0.3033 - accuracy: 0.8872 - val_loss: 0.8022 - val_accuracy: 0.7962 - 12s/epoch - 183ms/step
# Epoch 69/200
# 64/64 - 12s - loss: 0.2942 - accuracy: 0.8887 - val_loss: 0.9366 - val_accuracy: 0.7888 - 12s/epoch - 183ms/step
# Epoch 70/200
# 64/64 - 12s - loss: 0.2892 - accuracy: 0.8927 - val_loss: 0.5153 - val_accuracy: 0.8343 - 12s/epoch - 183ms/step
# Epoch 71/200
# 64/64 - 12s - loss: 0.2920 - accuracy: 0.8910 - val_loss: 0.5822 - val_accuracy: 0.8348 - 12s/epoch - 183ms/step
# Epoch 72/200
# 64/64 - 12s - loss: 0.2889 - accuracy: 0.8927 - val_loss: 0.5587 - val_accuracy: 0.8241 - 12s/epoch - 183ms/step
# Epoch 73/200
# 64/64 - 12s - loss: 0.2844 - accuracy: 0.8928 - val_loss: 0.5979 - val_accuracy: 0.8176 - 12s/epoch - 184ms/step
# Epoch 74/200
# 64/64 - 12s - loss: 0.2826 - accuracy: 0.8939 - val_loss: 0.6422 - val_accuracy: 0.8274 - 12s/epoch - 183ms/step
# Epoch 75/200
# 64/64 - 12s - loss: 0.2795 - accuracy: 0.8967 - val_loss: 0.5592 - val_accuracy: 0.8019 - 12s/epoch - 183ms/step
# Epoch 76/200
# 64/64 - 12s - loss: 0.2832 - accuracy: 0.8947 - val_loss: 0.5395 - val_accuracy: 0.8241 - 12s/epoch - 183ms/step
# Epoch 77/200
# 64/64 - 12s - loss: 0.2746 - accuracy: 0.8956 - val_loss: 0.5326 - val_accuracy: 0.8299 - 12s/epoch - 183ms/step
# Epoch 78/200
# 64/64 - 12s - loss: 0.2845 - accuracy: 0.8936 - val_loss: 0.5708 - val_accuracy: 0.8234 - 12s/epoch - 183ms/step
# Epoch 79/200
# 64/64 - 12s - loss: 0.2701 - accuracy: 0.8981 - val_loss: 0.7652 - val_accuracy: 0.8219 - 12s/epoch - 186ms/step
# Epoch 80/200
# 64/64 - 12s - loss: 0.2816 - accuracy: 0.8963 - val_loss: 0.5813 - val_accuracy: 0.8222 - 12s/epoch - 183ms/step
# Epoch 81/200
# 64/64 - 12s - loss: 0.2916 - accuracy: 0.8954 - val_loss: 0.5610 - val_accuracy: 0.8311 - 12s/epoch - 183ms/step
# Epoch 82/200
# 64/64 - 12s - loss: 0.2748 - accuracy: 0.8987 - val_loss: 0.5086 - val_accuracy: 0.8363 - 12s/epoch - 186ms/step
# Epoch 83/200
# 64/64 - 12s - loss: 0.2743 - accuracy: 0.8979 - val_loss: 0.5901 - val_accuracy: 0.8146 - 12s/epoch - 185ms/step
# Epoch 84/200
# 64/64 - 12s - loss: 0.2672 - accuracy: 0.9009 - val_loss: 0.6273 - val_accuracy: 0.8328 - 12s/epoch - 183ms/step
# Epoch 85/200
# 64/64 - 12s - loss: 0.2732 - accuracy: 0.9013 - val_loss: 0.5996 - val_accuracy: 0.8300 - 12s/epoch - 183ms/step
# Epoch 86/200
# 64/64 - 12s - loss: 0.2709 - accuracy: 0.8999 - val_loss: 0.5751 - val_accuracy: 0.8067 - 12s/epoch - 183ms/step
# Epoch 87/200
# 64/64 - 12s - loss: 0.2657 - accuracy: 0.9000 - val_loss: 0.5588 - val_accuracy: 0.8122 - 12s/epoch - 183ms/step
# Epoch 88/200
# 64/64 - 12s - loss: 0.2723 - accuracy: 0.9005 - val_loss: 0.6491 - val_accuracy: 0.7786 - 12s/epoch - 183ms/step
# Epoch 89/200
# 64/64 - 12s - loss: 0.2737 - accuracy: 0.9019 - val_loss: 0.5711 - val_accuracy: 0.8354 - 12s/epoch - 183ms/step
# Epoch 90/200
# 64/64 - 12s - loss: 0.2644 - accuracy: 0.9010 - val_loss: 0.6137 - val_accuracy: 0.8260 - 12s/epoch - 184ms/step
# Epoch 91/200
# 64/64 - 12s - loss: 0.2644 - accuracy: 0.9025 - val_loss: 0.5918 - val_accuracy: 0.8251 - 12s/epoch - 183ms/step
# Epoch 92/200
# 64/64 - 12s - loss: 0.2595 - accuracy: 0.9038 - val_loss: 0.6880 - val_accuracy: 0.8116 - 12s/epoch - 183ms/step
# Epoch 93/200
# 64/64 - 12s - loss: 0.2670 - accuracy: 0.9025 - val_loss: 0.5418 - val_accuracy: 0.8271 - 12s/epoch - 183ms/step
# Epoch 94/200
# 64/64 - 12s - loss: 0.2555 - accuracy: 0.9058 - val_loss: 0.6160 - val_accuracy: 0.8325 - 12s/epoch - 183ms/step
# Epoch 95/200
# 64/64 - 12s - loss: 0.2669 - accuracy: 0.9047 - val_loss: 0.7445 - val_accuracy: 0.8150 - 12s/epoch - 183ms/step
# Epoch 96/200
# 64/64 - 12s - loss: 0.2652 - accuracy: 0.9038 - val_loss: 0.6313 - val_accuracy: 0.8249 - 12s/epoch - 183ms/step
# Epoch 97/200
# 64/64 - 12s - loss: 0.2586 - accuracy: 0.9028 - val_loss: 0.8653 - val_accuracy: 0.8220 - 12s/epoch - 183ms/step
# Epoch 98/200
# 64/64 - 12s - loss: 0.2604 - accuracy: 0.9027 - val_loss: 0.6314 - val_accuracy: 0.8247 - 12s/epoch - 183ms/step
# Epoch 99/200
# 64/64 - 12s - loss: 0.2610 - accuracy: 0.9040 - val_loss: 0.6984 - val_accuracy: 0.8361 - 12s/epoch - 183ms/step
# Epoch 100/200
# 64/64 - 12s - loss: 0.2538 - accuracy: 0.9074 - val_loss: 0.6283 - val_accuracy: 0.8316 - 12s/epoch - 183ms/step
# Epoch 101/200
# 64/64 - 12s - loss: 0.2552 - accuracy: 0.9050 - val_loss: 0.6380 - val_accuracy: 0.8132 - 12s/epoch - 183ms/step
# Epoch 102/200
# 64/64 - 12s - loss: 0.2539 - accuracy: 0.9064 - val_loss: 0.6066 - val_accuracy: 0.8222 - 12s/epoch - 187ms/step
# Epoch 103/200
# 64/64 - 12s - loss: 0.2515 - accuracy: 0.9072 - val_loss: 0.6853 - val_accuracy: 0.8055 - 12s/epoch - 186ms/step
# Epoch 104/200
# 64/64 - 12s - loss: 0.2532 - accuracy: 0.9081 - val_loss: 0.7249 - val_accuracy: 0.7860 - 12s/epoch - 183ms/step
# Epoch 105/200
# 64/64 - 12s - loss: 0.2551 - accuracy: 0.9067 - val_loss: 0.7502 - val_accuracy: 0.7953 - 12s/epoch - 183ms/step
# Epoch 106/200
# 64/64 - 12s - loss: 0.2475 - accuracy: 0.9119 - val_loss: 0.6360 - val_accuracy: 0.8144 - 12s/epoch - 183ms/step
# Epoch 107/200
# 64/64 - 12s - loss: 0.2643 - accuracy: 0.9036 - val_loss: 0.6029 - val_accuracy: 0.8309 - 12s/epoch - 183ms/step
# Epoch 108/200
# 64/64 - 12s - loss: 0.2451 - accuracy: 0.9110 - val_loss: 0.8413 - val_accuracy: 0.7440 - 12s/epoch - 183ms/step
# Epoch 109/200
# 64/64 - 12s - loss: 0.2444 - accuracy: 0.9107 - val_loss: 0.9232 - val_accuracy: 0.8323 - 12s/epoch - 183ms/step
# Epoch 110/200
# 64/64 - 12s - loss: 0.2489 - accuracy: 0.9099 - val_loss: 0.6314 - val_accuracy: 0.8178 - 12s/epoch - 183ms/step
# Epoch 111/200
# 64/64 - 12s - loss: 0.2539 - accuracy: 0.9062 - val_loss: 0.7393 - val_accuracy: 0.8105 - 12s/epoch - 183ms/step
# Epoch 112/200
# 64/64 - 12s - loss: 0.2478 - accuracy: 0.9093 - val_loss: 0.6812 - val_accuracy: 0.8099 - 12s/epoch - 183ms/step
# Epoch 113/200
# 64/64 - 12s - loss: 0.2484 - accuracy: 0.9096 - val_loss: 0.5873 - val_accuracy: 0.8174 - 12s/epoch - 183ms/step
# Epoch 114/200
# 64/64 - 12s - loss: 0.2448 - accuracy: 0.9092 - val_loss: 0.6796 - val_accuracy: 0.8276 - 12s/epoch - 183ms/step
# Epoch 115/200
# 64/64 - 12s - loss: 0.2431 - accuracy: 0.9096 - val_loss: 0.6208 - val_accuracy: 0.8318 - 12s/epoch - 183ms/step
# Epoch 116/200
# 64/64 - 12s - loss: 0.2500 - accuracy: 0.9098 - val_loss: 0.8769 - val_accuracy: 0.8145 - 12s/epoch - 183ms/step
# Epoch 117/200
# 64/64 - 12s - loss: 0.2480 - accuracy: 0.9110 - val_loss: 0.6523 - val_accuracy: 0.8284 - 12s/epoch - 183ms/step
# Epoch 118/200
# 64/64 - 12s - loss: 0.2466 - accuracy: 0.9121 - val_loss: 0.6846 - val_accuracy: 0.8044 - 12s/epoch - 183ms/step
# Epoch 119/200
# 64/64 - 12s - loss: 0.2451 - accuracy: 0.9115 - val_loss: 0.6395 - val_accuracy: 0.8095 - 12s/epoch - 183ms/step
# Epoch 120/200
# 64/64 - 12s - loss: 0.2432 - accuracy: 0.9135 - val_loss: 0.6575 - val_accuracy: 0.8223 - 12s/epoch - 186ms/step
# Epoch 121/200
# 64/64 - 12s - loss: 0.2527 - accuracy: 0.9124 - val_loss: 0.8321 - val_accuracy: 0.8151 - 12s/epoch - 182ms/step
# Epoch 122/200
# 64/64 - 12s - loss: 0.2421 - accuracy: 0.9116 - val_loss: 0.6615 - val_accuracy: 0.8062 - 12s/epoch - 186ms/step
# Epoch 123/200
# 64/64 - 12s - loss: 0.2440 - accuracy: 0.9112 - val_loss: 0.8240 - val_accuracy: 0.8082 - 12s/epoch - 183ms/step
# Epoch 124/200
# 64/64 - 12s - loss: 0.2456 - accuracy: 0.9119 - val_loss: 0.7873 - val_accuracy: 0.8179 - 12s/epoch - 183ms/step
# Epoch 125/200
# 64/64 - 12s - loss: 0.2377 - accuracy: 0.9144 - val_loss: 0.7859 - val_accuracy: 0.8171 - 12s/epoch - 183ms/step
# Epoch 126/200
# 64/64 - 12s - loss: 0.2475 - accuracy: 0.9099 - val_loss: 0.6394 - val_accuracy: 0.8186 - 12s/epoch - 186ms/step
# Epoch 127/200
# 64/64 - 12s - loss: 0.2414 - accuracy: 0.9141 - val_loss: 0.7330 - val_accuracy: 0.8172 - 12s/epoch - 183ms/step
# Epoch 128/200
# 64/64 - 12s - loss: 0.2380 - accuracy: 0.9147 - val_loss: 0.8574 - val_accuracy: 0.8223 - 12s/epoch - 183ms/step
# Epoch 129/200
# 64/64 - 12s - loss: 0.2463 - accuracy: 0.9111 - val_loss: 0.8373 - val_accuracy: 0.8057 - 12s/epoch - 183ms/step
# Epoch 130/200
# 64/64 - 12s - loss: 0.2404 - accuracy: 0.9129 - val_loss: 0.7245 - val_accuracy: 0.8276 - 12s/epoch - 182ms/step
# Epoch 131/200
# 64/64 - 12s - loss: 0.2408 - accuracy: 0.9127 - val_loss: 0.6851 - val_accuracy: 0.8260 - 12s/epoch - 183ms/step
# Epoch 132/200
# 64/64 - 12s - loss: 0.2454 - accuracy: 0.9130 - val_loss: 0.7321 - val_accuracy: 0.8129 - 12s/epoch - 183ms/step
# Epoch 133/200
# 64/64 - 12s - loss: 0.2403 - accuracy: 0.9125 - val_loss: 0.6042 - val_accuracy: 0.8199 - 12s/epoch - 183ms/step
# Epoch 134/200
# 64/64 - 12s - loss: 0.2384 - accuracy: 0.9122 - val_loss: 0.7423 - val_accuracy: 0.7991 - 12s/epoch - 182ms/step
# Epoch 135/200
# 64/64 - 12s - loss: 0.2424 - accuracy: 0.9134 - val_loss: 0.6402 - val_accuracy: 0.8165 - 12s/epoch - 186ms/step
# Epoch 136/200
# 64/64 - 12s - loss: 0.2328 - accuracy: 0.9178 - val_loss: 1.0577 - val_accuracy: 0.8172 - 12s/epoch - 183ms/step
# Epoch 137/200
# 64/64 - 12s - loss: 0.2453 - accuracy: 0.9134 - val_loss: 0.6344 - val_accuracy: 0.8222 - 12s/epoch - 183ms/step
# Epoch 138/200
# 64/64 - 12s - loss: 0.2445 - accuracy: 0.9118 - val_loss: 0.6645 - val_accuracy: 0.8068 - 12s/epoch - 186ms/step
# Epoch 139/200
# 64/64 - 12s - loss: 0.2399 - accuracy: 0.9149 - val_loss: 0.6015 - val_accuracy: 0.8163 - 12s/epoch - 183ms/step
# Epoch 140/200
# 64/64 - 12s - loss: 0.2343 - accuracy: 0.9151 - val_loss: 0.6403 - val_accuracy: 0.8000 - 12s/epoch - 183ms/step
# Epoch 141/200
# 64/64 - 12s - loss: 0.2365 - accuracy: 0.9147 - val_loss: 0.7020 - val_accuracy: 0.7860 - 12s/epoch - 183ms/step
# Epoch 142/200
# 64/64 - 12s - loss: 0.2365 - accuracy: 0.9148 - val_loss: 0.8988 - val_accuracy: 0.8158 - 12s/epoch - 183ms/step
# Epoch 143/200
# 64/64 - 12s - loss: 0.2430 - accuracy: 0.9120 - val_loss: 0.8751 - val_accuracy: 0.8162 - 12s/epoch - 183ms/step
# Epoch 144/200
# 64/64 - 12s - loss: 0.2393 - accuracy: 0.9150 - val_loss: 0.8467 - val_accuracy: 0.8307 - 12s/epoch - 183ms/step
# Epoch 145/200
# 64/64 - 12s - loss: 0.2363 - accuracy: 0.9166 - val_loss: 0.7669 - val_accuracy: 0.8159 - 12s/epoch - 183ms/step
# Epoch 146/200
# 64/64 - 12s - loss: 0.2437 - accuracy: 0.9125 - val_loss: 0.6439 - val_accuracy: 0.8106 - 12s/epoch - 186ms/step
# Epoch 147/200
# 64/64 - 12s - loss: 0.2457 - accuracy: 0.9134 - val_loss: 0.6671 - val_accuracy: 0.8238 - 12s/epoch - 183ms/step
# Epoch 148/200
# 64/64 - 12s - loss: 0.2350 - accuracy: 0.9167 - val_loss: 0.6584 - val_accuracy: 0.8280 - 12s/epoch - 183ms/step
# Epoch 149/200
# 64/64 - 12s - loss: 0.2414 - accuracy: 0.9124 - val_loss: 0.7021 - val_accuracy: 0.8281 - 12s/epoch - 183ms/step
# Epoch 150/200
# 64/64 - 12s - loss: 0.2437 - accuracy: 0.9130 - val_loss: 0.7343 - val_accuracy: 0.8083 - 12s/epoch - 183ms/step
# Epoch 151/200
# 64/64 - 12s - loss: 0.2369 - accuracy: 0.9151 - val_loss: 0.7486 - val_accuracy: 0.8000 - 12s/epoch - 183ms/step
# Epoch 152/200
# 64/64 - 12s - loss: 0.2406 - accuracy: 0.9127 - val_loss: 0.8456 - val_accuracy: 0.8046 - 12s/epoch - 183ms/step
# Epoch 153/200
# 64/64 - 12s - loss: 0.2348 - accuracy: 0.9160 - val_loss: 1.1113 - val_accuracy: 0.7831 - 12s/epoch - 183ms/step
# Epoch 154/200
# 64/64 - 12s - loss: 0.2386 - accuracy: 0.9145 - val_loss: 0.7150 - val_accuracy: 0.8188 - 12s/epoch - 183ms/step
# Epoch 155/200
# 64/64 - 12s - loss: 0.2287 - accuracy: 0.9176 - val_loss: 0.6145 - val_accuracy: 0.8161 - 12s/epoch - 183ms/step
# Epoch 156/200
# 64/64 - 12s - loss: 0.2296 - accuracy: 0.9181 - val_loss: 0.9211 - val_accuracy: 0.7950 - 12s/epoch - 183ms/step
# Epoch 157/200
# 64/64 - 12s - loss: 0.2278 - accuracy: 0.9177 - val_loss: 1.0993 - val_accuracy: 0.7958 - 12s/epoch - 183ms/step
# Epoch 158/200
# 64/64 - 12s - loss: 0.2325 - accuracy: 0.9172 - val_loss: 0.7911 - val_accuracy: 0.8238 - 12s/epoch - 182ms/step
# Epoch 159/200
# 64/64 - 12s - loss: 0.2262 - accuracy: 0.9191 - val_loss: 0.7142 - val_accuracy: 0.8120 - 12s/epoch - 183ms/step
# Epoch 160/200
# 64/64 - 12s - loss: 0.2403 - accuracy: 0.9141 - val_loss: 0.6634 - val_accuracy: 0.8246 - 12s/epoch - 183ms/step
# Epoch 161/200
# 64/64 - 12s - loss: 0.2317 - accuracy: 0.9161 - val_loss: 1.0496 - val_accuracy: 0.8126 - 12s/epoch - 183ms/step
# Epoch 162/200
# 64/64 - 12s - loss: 0.2372 - accuracy: 0.9140 - val_loss: 0.8059 - val_accuracy: 0.8176 - 12s/epoch - 183ms/step
# Epoch 163/200
# 64/64 - 12s - loss: 0.2418 - accuracy: 0.9140 - val_loss: 0.7838 - val_accuracy: 0.8186 - 12s/epoch - 183ms/step
# Epoch 164/200
# 64/64 - 12s - loss: 0.2329 - accuracy: 0.9169 - val_loss: 0.8664 - val_accuracy: 0.8061 - 12s/epoch - 183ms/step
# Epoch 165/200
# 64/64 - 12s - loss: 0.2354 - accuracy: 0.9141 - val_loss: 0.7025 - val_accuracy: 0.8217 - 12s/epoch - 183ms/step
# Epoch 166/200
# 64/64 - 12s - loss: 0.2364 - accuracy: 0.9168 - val_loss: 0.8378 - val_accuracy: 0.8361 - 12s/epoch - 186ms/step
# Epoch 167/200
# 64/64 - 12s - loss: 0.2273 - accuracy: 0.9208 - val_loss: 0.9099 - val_accuracy: 0.8078 - 12s/epoch - 183ms/step
# Epoch 168/200
# 64/64 - 12s - loss: 0.2483 - accuracy: 0.9131 - val_loss: 0.6869 - val_accuracy: 0.8107 - 12s/epoch - 183ms/step
# Epoch 169/200
# 64/64 - 12s - loss: 0.2375 - accuracy: 0.9170 - val_loss: 0.9268 - val_accuracy: 0.8100 - 12s/epoch - 183ms/step
# Epoch 170/200
# 64/64 - 12s - loss: 0.2447 - accuracy: 0.9135 - val_loss: 0.6793 - val_accuracy: 0.8164 - 12s/epoch - 183ms/step
# Epoch 171/200
# 64/64 - 12s - loss: 0.2377 - accuracy: 0.9135 - val_loss: 0.6967 - val_accuracy: 0.7985 - 12s/epoch - 183ms/step
# Epoch 172/200
# 64/64 - 12s - loss: 0.2355 - accuracy: 0.9141 - val_loss: 0.6337 - val_accuracy: 0.8215 - 12s/epoch - 183ms/step
# Epoch 173/200
# 64/64 - 12s - loss: 0.2359 - accuracy: 0.9150 - val_loss: 0.6329 - val_accuracy: 0.8140 - 12s/epoch - 183ms/step
# Epoch 174/200
# 64/64 - 12s - loss: 0.2371 - accuracy: 0.9132 - val_loss: 0.7681 - val_accuracy: 0.8078 - 12s/epoch - 183ms/step
# Epoch 175/200
# 64/64 - 12s - loss: 0.2341 - accuracy: 0.9155 - val_loss: 0.6700 - val_accuracy: 0.8188 - 12s/epoch - 183ms/step
# Epoch 176/200
# 64/64 - 12s - loss: 0.2298 - accuracy: 0.9167 - val_loss: 0.8294 - val_accuracy: 0.8189 - 12s/epoch - 183ms/step
# Epoch 177/200
# 64/64 - 12s - loss: 0.2347 - accuracy: 0.9172 - val_loss: 0.7284 - val_accuracy: 0.8013 - 12s/epoch - 183ms/step
# Epoch 178/200
# 64/64 - 12s - loss: 0.2414 - accuracy: 0.9162 - val_loss: 1.1027 - val_accuracy: 0.7911 - 12s/epoch - 183ms/step
# Epoch 179/200
# 64/64 - 12s - loss: 0.2403 - accuracy: 0.9149 - val_loss: 0.8996 - val_accuracy: 0.7947 - 12s/epoch - 183ms/step
# Epoch 180/200
# 64/64 - 12s - loss: 0.2418 - accuracy: 0.9154 - val_loss: 0.7117 - val_accuracy: 0.8213 - 12s/epoch - 183ms/step
# Epoch 181/200
# 64/64 - 12s - loss: 0.2333 - accuracy: 0.9161 - val_loss: 0.8152 - val_accuracy: 0.8284 - 12s/epoch - 183ms/step
# Epoch 182/200
# 64/64 - 12s - loss: 0.2341 - accuracy: 0.9157 - val_loss: 0.6661 - val_accuracy: 0.8031 - 12s/epoch - 183ms/step
# Epoch 183/200
# 64/64 - 12s - loss: 0.2379 - accuracy: 0.9165 - val_loss: 0.8498 - val_accuracy: 0.8265 - 12s/epoch - 183ms/step
# Epoch 184/200
# 64/64 - 12s - loss: 0.2414 - accuracy: 0.9144 - val_loss: 0.7682 - val_accuracy: 0.8260 - 12s/epoch - 183ms/step
# Epoch 185/200
# 64/64 - 12s - loss: 0.2412 - accuracy: 0.9154 - val_loss: 0.9261 - val_accuracy: 0.7871 - 12s/epoch - 183ms/step
# Epoch 186/200
# 64/64 - 12s - loss: 0.2388 - accuracy: 0.9157 - val_loss: 0.6555 - val_accuracy: 0.8117 - 12s/epoch - 183ms/step
# Epoch 187/200
# 64/64 - 12s - loss: 0.2376 - accuracy: 0.9147 - val_loss: 0.6764 - val_accuracy: 0.8198 - 12s/epoch - 182ms/step
# Epoch 188/200
# 64/64 - 12s - loss: 0.2352 - accuracy: 0.9161 - val_loss: 0.9289 - val_accuracy: 0.8163 - 12s/epoch - 183ms/step
# Epoch 189/200
# 64/64 - 12s - loss: 0.2408 - accuracy: 0.9153 - val_loss: 0.7966 - val_accuracy: 0.8049 - 12s/epoch - 183ms/step
# Epoch 190/200
# 64/64 - 12s - loss: 0.2346 - accuracy: 0.9178 - val_loss: 0.6765 - val_accuracy: 0.8106 - 12s/epoch - 183ms/step
# Epoch 191/200
# 64/64 - 12s - loss: 0.2393 - accuracy: 0.9174 - val_loss: 0.6756 - val_accuracy: 0.8052 - 12s/epoch - 183ms/step
# Epoch 192/200
# 64/64 - 12s - loss: 0.2370 - accuracy: 0.9158 - val_loss: 0.8778 - val_accuracy: 0.7734 - 12s/epoch - 183ms/step
# Epoch 193/200
# 64/64 - 12s - loss: 0.2414 - accuracy: 0.9145 - val_loss: 0.5926 - val_accuracy: 0.8009 - 12s/epoch - 183ms/step
# Epoch 194/200
# 64/64 - 12s - loss: 0.2374 - accuracy: 0.9172 - val_loss: 0.6397 - val_accuracy: 0.8092 - 12s/epoch - 183ms/step
# Epoch 195/200
# 64/64 - 12s - loss: 0.2376 - accuracy: 0.9161 - val_loss: 0.8281 - val_accuracy: 0.8064 - 12s/epoch - 183ms/step
# Epoch 196/200
# 64/64 - 12s - loss: 0.2355 - accuracy: 0.9160 - val_loss: 1.1373 - val_accuracy: 0.7877 - 12s/epoch - 183ms/step
# Epoch 197/200
# 64/64 - 12s - loss: 0.2398 - accuracy: 0.9124 - val_loss: 0.7938 - val_accuracy: 0.7793 - 12s/epoch - 186ms/step
# Epoch 198/200
# 64/64 - 12s - loss: 0.2485 - accuracy: 0.9138 - val_loss: 0.8701 - val_accuracy: 0.8091 - 12s/epoch - 183ms/step
# Epoch 199/200
# 64/64 - 12s - loss: 0.2324 - accuracy: 0.9187 - val_loss: 0.6707 - val_accuracy: 0.7978 - 12s/epoch - 186ms/step
# Epoch 200/200
# 64/64 - 12s - loss: 0.2345 - accuracy: 0.9164 - val_loss: 0.7490 - val_accuracy: 0.7945 - 12s/epoch - 183ms/step
# Train loss: 0.0926806777715683
# Train accuracy: 0.9805552959442139
# Test loss: 0.7489866614341736
# Test accuracy: 0.7944597005844116

# %%
# Loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# Accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
from sklearn import metrics
y_score = model.predict(x_test)
fpr, tpr, thresholds = metrics.roc_curve(y_test.ravel(),y_score.ravel())
plt.plot(fpr, tpr, c = 'r', lw = 2, alpha = 0.7)
plt.plot((0, 1), (0, 1), c = '#808080', lw = 1, ls = '--', alpha = 0.7)
plt.xlim((-0.01, 1.02))
plt.ylim((-0.01, 1.02))
plt.xticks(np.arange(0, 1.1, 0.1))
plt.yticks(np.arange(0, 1.1, 0.1))
plt.xlabel('False Positive Rate', fontsize=13)
plt.ylabel('True Positive Rate', fontsize=13)
plt.grid(b=True, ls=':')
plt.legend(loc='lower right', fancybox=True, framealpha=0.8, fontsize=12)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
pre_train = model.predict(x_train)
pre_train = np.argmax(pre_train,axis=1)
y_train = np.argmax(y_train,axis=1)
pre_test = model.predict(x_test)
pre_test = np.argmax(pre_test,axis=1)
y_test = np.argmax(y_test,axis=1)
# 评估指标
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm_train = confusion_matrix(y_train,pre_train)
cm_normalized_train = cm_train.astype('float') / cm_train.sum(axis=1)[:, np.newaxis]
cm_test = confusion_matrix(y_test,pre_test)
cm_normalized_test = cm_test.astype('float') / cm_test.sum(axis=1)[:, np.newaxis]
# 混淆矩阵图
sns.set()
f,ax=plt.subplots()
sns.heatmap(cm_normalized_train,annot=True,ax=ax)
ax.set_title('train confusion matrix')
ax.set_xlabel('predict') 
ax.set_ylabel('true') 

sns.set()
f,ax=plt.subplots()
sns.heatmap(cm_normalized_test,annot=True,ax=ax) 
ax.set_title('test confusion matrix') 
ax.set_xlabel('predict') 
ax.set_ylabel('true')
# Out:
# Text(30.5, 0.5, 'true')

# %%
# 评估指标
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
acc = accuracy_score(y_test,pre_test)
recall = recall_score(y_test,pre_test, average='macro')
prc = precision_score(y_test,pre_test, average='macro')
f1 = f1_score(y_test,pre_test, average='macro')
print('Accuracy:',acc)
print('Recall:',recall)
print('Precision:',prc)
print('F1:',f1)
# Out:
# Accuracy: 0.7944596766568971
# Recall: 0.7303474683150215
# Precision: 0.7338659210402978
# F1: 0.7269052744715258
